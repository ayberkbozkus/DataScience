# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
print(digits.DESCR)
# Out:
# .. _digits_dataset:
#
# Optical recognition of handwritten digits dataset
# --------------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 5620
#     :Number of Attributes: 64
#     :Attribute Information: 8x8 image of integer pixels in the range 0..16.
#     :Missing Attribute Values: None
#     :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)
#     :Date: July; 1998
#
# This is a copy of the test set of the UCI ML hand-written digits datasets
# https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits
#
# The data set contains images of hand-written digits: 10 classes where
# each class refers to a digit.
#
# Preprocessing programs made available by NIST were used to extract
# normalized bitmaps of handwritten digits from a preprinted form. From a
# total of 43 people, 30 contributed to the training set and different 13
# to the test set. 32x32 bitmaps are divided into nonoverlapping blocks of
# 4x4 and the number of on pixels are counted in each block. This generates
# an input matrix of 8x8 where each element is an integer in the range
# 0..16. This reduces dimensionality and gives invariance to small
# distortions.
#
# For info on NIST preprocessing routines, see M. D. Garris, J. L. Blue, G.
# T. Candela, D. L. Dimmick, J. Geist, P. J. Grother, S. A. Janet, and C.
# L. Wilson, NIST Form-Based Handprint Recognition System, NISTIR 5469,
# 1994.
#
# .. topic:: References
#
#   - C. Kaynak (1995) Methods of Combining Multiple Classifiers and Their
#     Applications to Handwritten Digit Recognition, MSc Thesis, Institute of
#     Graduate Studies in Science and Engineering, Bogazici University.
#   - E. Alpaydin, C. Kaynak (1998) Cascading Classifiers, Kybernetika.
#   - Ken Tang and Ponnuthurai N. Suganthan and Xi Yao and A. Kai Qin.
#     Linear dimensionalityreduction using relevance weighted LDA. School of
#     Electrical and Electronic Engineering Nanyang Technological University.
#     2005.
#   - Claudio Gentile. A New Approximate Maximal Margin Classification
#     Algorithm. NIPS. 2000.

# %%
param_grid = [{'kernel':['rbf'],'gamma':[1e-3,1e-4],'C':[1,10,100,1000]},
             {'kernel':['linear'],'C':[1,10,100,1000]}]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
grid_search = GridSearchCV(SVC(),param_grid,cv=5)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, random_state = 0)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']},
#                          {'C': [1, 10, 100, 1000], 'kernel': ['linear']}])

# %%
grid_search.score(X_test,y_test)
# Out:
# 0.9933333333333333

# %%
grid_search.best_params_
# Out:
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
grid_search.best_score_
# Out:
# 0.9918353297535452

# %%
grid_search.best_estimator_
# Out:
# SVC(C=10, gamma=0.001)

# %%
grid_search.cv_results_
# Out:
# {'mean_fit_time': array([0.06352463, 0.05422702, 0.0638166 , 0.03003979, 0.06166906,
#         0.03439913, 0.06266727, 0.030867  , 0.02239723, 0.02160621,
#         0.02719617, 0.0224452 ]),
#  'std_fit_time': array([0.00189208, 0.00184966, 0.00359248, 0.000566  , 0.00164432,
#         0.00696157, 0.00159319, 0.00120846, 0.00081187, 0.00072987,
#         0.00768113, 0.00101904]),
#  'mean_score_time': array([0.01341496, 0.01581664, 0.0130878 , 0.00935936, 0.01313391,
#         0.01020274, 0.01321673, 0.00933824, 0.00606828, 0.00615516,
#         0.00768175, 0.00585852]),
#  'std_score_time': array([0.00037327, 0.00066062, 0.00013608, 0.00041495, 0.00066043,
#         0.00281492, 0.00024011, 0.00029482, 0.00039734, 0.00014434,
#         0.00173655, 0.00042976]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 100, 100, 1000, 1000, 1, 10, 100, 1000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_gamma': masked_array(data=[0.001, 0.0001, 0.001, 0.0001, 0.001, 0.0001, 0.001,
#                     0.0001, --, --, --, --],
#               mask=[False, False, False, False, False, False, False, False,
#                      True,  True,  True,  True],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf',
#                     'linear', 'linear', 'linear', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'gamma': 0.001, 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'},
#   {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'},
#   {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 100, 'kernel': 'linear'},
#   {'C': 1000, 'kernel': 'linear'}],
#  'split0_test_score': array([0.99259259, 0.96666667, 0.98888889, 0.98518519, 0.98888889,
#         0.98518519, 0.98888889, 0.98518519, 0.98148148, 0.98148148,
#         0.98148148, 0.98148148]),
#  'split1_test_score': array([0.99259259, 0.97407407, 0.99259259, 0.99259259, 0.99259259,
#         0.98888889, 0.99259259, 0.98888889, 0.97037037, 0.97037037,
#         0.97037037, 0.97037037]),
#  'split2_test_score': array([0.98884758, 0.96282528, 0.99256506, 0.98141264, 0.99256506,
#         0.98141264, 0.99256506, 0.98141264, 0.97769517, 0.97769517,
#         0.97769517, 0.97769517]),
#  'split3_test_score': array([0.98513011, 0.97026022, 0.98884758, 0.98141264, 0.98884758,
#         0.98513011, 0.98884758, 0.98513011, 0.98141264, 0.98141264,
#         0.98141264, 0.98141264]),
#  'split4_test_score': array([0.99628253, 0.98141264, 0.99628253, 0.99628253, 0.99628253,
#         1.        , 0.99628253, 1.        , 0.99628253, 0.99628253,
#         0.99628253, 0.99628253]),
#  'mean_test_score': array([0.99108908, 0.97104778, 0.99183533, 0.98737712, 0.99183533,
#         0.98812337, 0.99183533, 0.98812337, 0.98144844, 0.98144844,
#         0.98144844, 0.98144844]),
#  'std_test_score': array([0.00379543, 0.00638769, 0.00277459, 0.0060409 , 0.00277459,
#         0.00639166, 0.00277459, 0.00639166, 0.00844823, 0.00844823,
#         0.00844823, 0.00844823]),
#  'rank_test_score': array([ 4, 12,  1,  7,  1,  5,  1,  5,  8,  8,  8,  8], dtype=int32)}

# %%
import pandas as pd

# %%
result = pd.DataFrame(grid_search.cv_results_)
result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.063525      0.001892         0.013415        0.000373       1
# 1        0.054227      0.001850         0.015817        0.000661       1
# 2        0.063817      0.003592         0.013088        0.000136      10
# 3        0.030040      0.000566         0.009359        0.000415      10
# 4        0.061669      0.001644         0.013134        0.000660     100
# 5        0.034399      0.006962         0.010203        0.002815     100
# 6        0.062667      0.001593         0.013217        0.000240    1000
# 7        0.030867      0.001208         0.009338        0.000295    1000
# 8        0.022397      0.000812         0.006068        0.000397       1
# 9        0.021606      0.000730         0.006155        0.000144      10
# 10       0.027196      0.007681         0.007682        0.001737     100
# 11       0.022445      0.001019         0.005859        0.000430    1000
#
#    param_gamma param_kernel                                         params  \
# 0        0.001          rbf      {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 1       0.0001          rbf     {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 2        0.001          rbf     {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 3       0.0001          rbf    {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 4        0.001          rbf    {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 5       0.0001          rbf   {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 6        0.001          rbf   {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 7       0.0001          rbf  {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 8          NaN       linear                   {'C': 1, 'kernel': 'linear'}
# 9          NaN       linear                  {'C': 10, 'kernel': 'linear'}
# 10         NaN       linear                 {'C': 100, 'kernel': 'linear'}
# 11         NaN       linear                {'C': 1000, 'kernel': 'linear'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.992593           0.992593           0.988848
# 1            0.966667           0.974074           0.962825
# 2            0.988889           0.992593           0.992565
# 3            0.985185           0.992593           0.981413
# 4            0.988889           0.992593           0.992565
# 5            0.985185           0.988889           0.981413
# 6            0.988889           0.992593           0.992565
# 7            0.985185           0.988889           0.981413
# 8            0.981481           0.970370           0.977695
# 9            0.981481           0.970370           0.977695
# 10           0.981481           0.970370           0.977695
# 11           0.981481           0.970370           0.977695
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.985130           0.996283         0.991089        0.003795
# 1            0.970260           0.981413         0.971048        0.006388
# 2            0.988848           0.996283         0.991835        0.002775
# 3            0.981413           0.996283         0.987377        0.006041
# 4            0.988848           0.996283         0.991835        0.002775
# 5            0.985130           1.000000         0.988123        0.006392
# 6            0.988848           0.996283         0.991835        0.002775
# 7            0.985130           1.000000         0.988123        0.006392
# 8            0.981413           0.996283         0.981448        0.008448
# 9            0.981413           0.996283         0.981448        0.008448
# 10           0.981413           0.996283         0.981448        0.008448
# 11           0.981413           0.996283         0.981448        0.008448
#
#     rank_test_score
# 0                 4
# 1                12
# 2                 1
# 3                 7
# 4                 1
# 5                 5
# 6                 1
# 7                 5
# 8                 8
# 9                 8
# 10                8
# 11                8

# %%
result.T
# Out:
#                                                           0   \
# mean_fit_time                                      0.0635246
# std_fit_time                                      0.00189208
# mean_score_time                                     0.013415
# std_score_time                                   0.000373266
# param_C                                                    1
# param_gamma                                            0.001
# param_kernel                                             rbf
# params             {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# split0_test_score                                   0.992593
# split1_test_score                                   0.992593
# split2_test_score                                   0.988848
# split3_test_score                                    0.98513
# split4_test_score                                   0.996283
# mean_test_score                                     0.991089
# std_test_score                                    0.00379543
# rank_test_score                                            4
#
#                                                            1   \
# mean_fit_time                                        0.054227
# std_fit_time                                       0.00184966
# mean_score_time                                     0.0158166
# std_score_time                                    0.000660618
# param_C                                                     1
# param_gamma                                            0.0001
# param_kernel                                              rbf
# params             {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# split0_test_score                                    0.966667
# split1_test_score                                    0.974074
# split2_test_score                                    0.962825
# split3_test_score                                     0.97026
# split4_test_score                                    0.981413
# mean_test_score                                      0.971048
# std_test_score                                     0.00638769
# rank_test_score                                            12
#
#                                                            2   \
# mean_fit_time                                       0.0638166
# std_fit_time                                       0.00359248
# mean_score_time                                     0.0130878
# std_score_time                                    0.000136076
# param_C                                                    10
# param_gamma                                             0.001
# param_kernel                                              rbf
# params             {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# split0_test_score                                    0.988889
# split1_test_score                                    0.992593
# split2_test_score                                    0.992565
# split3_test_score                                    0.988848
# split4_test_score                                    0.996283
# mean_test_score                                      0.991835
# std_test_score                                     0.00277459
# rank_test_score                                             1
#
#                                                             3   \
# mean_fit_time                                        0.0300398
# std_fit_time                                       0.000566004
# mean_score_time                                     0.00935936
# std_score_time                                     0.000414952
# param_C                                                     10
# param_gamma                                             0.0001
# param_kernel                                               rbf
# params             {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# split0_test_score                                     0.985185
# split1_test_score                                     0.992593
# split2_test_score                                     0.981413
# split3_test_score                                     0.981413
# split4_test_score                                     0.996283
# mean_test_score                                       0.987377
# std_test_score                                       0.0060409
# rank_test_score                                              7
#
#                                                             4   \
# mean_fit_time                                        0.0616691
# std_fit_time                                        0.00164432
# mean_score_time                                      0.0131339
# std_score_time                                     0.000660429
# param_C                                                    100
# param_gamma                                              0.001
# param_kernel                                               rbf
# params             {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# split0_test_score                                     0.988889
# split1_test_score                                     0.992593
# split2_test_score                                     0.992565
# split3_test_score                                     0.988848
# split4_test_score                                     0.996283
# mean_test_score                                       0.991835
# std_test_score                                      0.00277459
# rank_test_score                                              1
#
#                                                              5   \
# mean_fit_time                                         0.0343991
# std_fit_time                                         0.00696157
# mean_score_time                                       0.0102027
# std_score_time                                       0.00281492
# param_C                                                     100
# param_gamma                                              0.0001
# param_kernel                                                rbf
# params             {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# split0_test_score                                      0.985185
# split1_test_score                                      0.988889
# split2_test_score                                      0.981413
# split3_test_score                                       0.98513
# split4_test_score                                             1
# mean_test_score                                        0.988123
# std_test_score                                       0.00639166
# rank_test_score                                               5
#
#                                                              6   \
# mean_fit_time                                         0.0626673
# std_fit_time                                         0.00159319
# mean_score_time                                       0.0132167
# std_score_time                                      0.000240113
# param_C                                                    1000
# param_gamma                                               0.001
# param_kernel                                                rbf
# params             {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# split0_test_score                                      0.988889
# split1_test_score                                      0.992593
# split2_test_score                                      0.992565
# split3_test_score                                      0.988848
# split4_test_score                                      0.996283
# mean_test_score                                        0.991835
# std_test_score                                       0.00277459
# rank_test_score                                               1
#
#                                                               7   \
# mean_fit_time                                           0.030867
# std_fit_time                                          0.00120846
# mean_score_time                                       0.00933824
# std_score_time                                       0.000294819
# param_C                                                     1000
# param_gamma                                               0.0001
# param_kernel                                                 rbf
# params             {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# split0_test_score                                       0.985185
# split1_test_score                                       0.988889
# split2_test_score                                       0.981413
# split3_test_score                                        0.98513
# split4_test_score                                              1
# mean_test_score                                         0.988123
# std_test_score                                        0.00639166
# rank_test_score                                                5
#
#                                              8   \
# mean_fit_time                         0.0223972
# std_fit_time                        0.000811872
# mean_score_time                      0.00606828
# std_score_time                      0.000397339
# param_C                                       1
# param_gamma                                 NaN
# param_kernel                             linear
# params             {'C': 1, 'kernel': 'linear'}
# split0_test_score                      0.981481
# split1_test_score                       0.97037
# split2_test_score                      0.977695
# split3_test_score                      0.981413
# split4_test_score                      0.996283
# mean_test_score                        0.981448
# std_test_score                       0.00844823
# rank_test_score                               8
#
#                                               9   \
# mean_fit_time                          0.0216062
# std_fit_time                         0.000729867
# mean_score_time                       0.00615516
# std_score_time                       0.000144345
# param_C                                       10
# param_gamma                                  NaN
# param_kernel                              linear
# params             {'C': 10, 'kernel': 'linear'}
# split0_test_score                       0.981481
# split1_test_score                        0.97037
# split2_test_score                       0.977695
# split3_test_score                       0.981413
# split4_test_score                       0.996283
# mean_test_score                         0.981448
# std_test_score                        0.00844823
# rank_test_score                                8
#
#                                                10  \
# mean_fit_time                           0.0271962
# std_fit_time                           0.00768113
# mean_score_time                        0.00768175
# std_score_time                         0.00173655
# param_C                                       100
# param_gamma                                   NaN
# param_kernel                               linear
# params             {'C': 100, 'kernel': 'linear'}
# split0_test_score                        0.981481
# split1_test_score                         0.97037
# split2_test_score                        0.977695
# split3_test_score                        0.981413
# split4_test_score                        0.996283
# mean_test_score                          0.981448
# std_test_score                         0.00844823
# rank_test_score                                 8
#
#                                                 11
# mean_fit_time                            0.0224452
# std_fit_time                            0.00101904
# mean_score_time                         0.00585852
# std_score_time                         0.000429762
# param_C                                       1000
# param_gamma                                    NaN
# param_kernel                                linear
# params             {'C': 1000, 'kernel': 'linear'}
# split0_test_score                         0.981481
# split1_test_score                          0.97037
# split2_test_score                         0.977695
# split3_test_score                         0.981413
# split4_test_score                         0.996283
# mean_test_score                           0.981448
# std_test_score                          0.00844823
# rank_test_score                                  8

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(GridSearchCV(SVC(),param_grid, cv=5),digits.data,digits.target, cv=5)
score
# Out:
# array([0.97777778, 0.95      , 0.98328691, 0.98607242, 0.9637883 ])

# %%
score.mean()
# Out:
# 0.972185082017951
